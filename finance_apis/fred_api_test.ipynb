# %% [markdown]
# # Testing FRED api

# %%
import pandas as pd
import pandas_datareader.data as web
from datetime import datetime
import matplotlib.pyplot as plt

start = datetime(2019,1,1)
end = datetime(2022,7,22)

gas_prices = web.DataReader('APUS37B74714', 'fred', start, end)
print(gas_prices.info())
gas_prices.reset_index(inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 42 entries, 2019-01-01 to 2022-06-01
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   APUS37B74714  42 non-null     float64
# dtypes: float64(1)
# memory usage: 672.0 bytes
# None

# %%
x = gas_prices['DATE']
y = gas_prices['APUS37B74714']
plt.plot(x, y)
plt.xlabel("Date")
plt.ylabel('Price USD')
plt.title("Houston Texas Gas Prices")
plt.show()
